# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Analyze student test performance.
#Visualize the data
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# ...

# %%
#display number of columns and rows in data 
df.shape
# Out:
# (212331, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
#Visualize the data from the bottom 
df.tail(5)
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
#average number of students tested in NYC 
df['Total Tested'].mean()
# Out:
# 49.36420023453947

# %%
#list schools and average number of students tested
df.groupby(['School Name'])['Total Tested'].median()
# Out:
# School Name
# 47 The American Sign Language and English Secondar    12.0
# A. Philip Randolph Campus High School                 51.0
# ACORN Community High School                           11.0
# Abraham Lincoln High School                           86.0
# Abraham Lincoln Yabc                                  10.0
#                                                       ...
# Young Women's Leadership School                       22.0
# Young Women's Leadership School of Brooklyn           13.0
# Young Women's Leadership School of the Bronx          19.5
# Young Women's Leadership School, Astoria              24.5
# Young Women's Leadership School, Queens               21.0
# Name: Total Tested, Length: 1012, dtype: float64

# %%
#display school DBN max and min number of students tested
df.groupby(['School DBN'])['Total Tested'].count().sort_values(ascending=False)
# Out:
# School DBN
# 22K425    490
# 26Q430    490
# 21K525    489
# 30Q450    489
# 21K540    488
#          ...
# 06M328      5
# 84M385      5
# 84K379      5
# 11X498      5
# 19K302      5
# Name: Total Tested, Length: 1018, dtype: int64

# %%
#display select columns 
df[['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year', 'Total Tested', 'Mean Score', 'Percent Scoring Below 65', 'Percent Scoring 80 or Above']]
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
#show all tests and how many students were tested 
df.groupby(['Regents Exam'])['Total Tested'].count()
# Out:
# Regents Exam
# Algebra2/Trigonometry              10788
# Common Core Algebra                29254
# Common Core Algebra2                7915
# Common Core English                19878
# Common Core Geometry               15267
# English                            11091
# Geometry                            8509
# Global History and Geography       19192
# Integrated Algebra                 11022
# Living Environment                 25539
# Physical Settings/Chemistry        11670
# Physical Settings/Earth Science    15971
# Physical Settings/Physics           5799
# U.S. History and Government        20426
# Name: Total Tested, dtype: int64

# %%
#pick any school in dataset as an initial comparison point. 
#Young Women's Leadership School, Astoria DBN: 30Q286, secondary school level 
df[df['School DBN'] =='30Q286']
# Out:
#        School DBN                               School Name      School Level  \
# 16435      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16436      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16437      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16438      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16439      30Q286  Young Women's Leadership School, Astoria  Secondary School
# ...           ...                                       ...               ...
# 202089     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202090     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202091     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202092     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202093     30Q286  Young Women's Leadership School, Astoria  Secondary School
#
# ...

# %%
#display select columns for all schools 
df2=df[['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year', 'Total Tested', 'Mean Score', 'Percent Scoring Below 65', 'Percent Scoring 80 or Above']]

# %%
df2.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score  \
# 0  Common Core Algebra  2017             4          s
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3          s
# 4  Common Core Algebra  2017             2          s
#
#   Percent Scoring Below 65 Percent Scoring 80 or Above
# 0                        s                           s
# 1                      6.3                        43.8
# 2                     11.1                        22.2
# 3                        s                           s
# ...

# %%
#filter by specific school and select columns 
df2[df2['School DBN'] =='30Q286']
# Out:
#        School DBN                               School Name      School Level  \
# 16435      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16436      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16437      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16438      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16439      30Q286  Young Women's Leadership School, Astoria  Secondary School
# ...           ...                                       ...               ...
# 202089     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202090     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202091     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202092     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202093     30Q286  Young Women's Leadership School, Astoria  Secondary School
#
# ...

# %%
values=["30Q286", "Common Core Algebra"]
print(df2[(df2["School DBN"]).isin(values)])
# Out:
#        School DBN                               School Name      School Level  \
# 16435      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16436      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16437      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16438      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16439      30Q286  Young Women's Leadership School, Astoria  Secondary School
# ...           ...                                       ...               ...
# 202089     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202090     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202091     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202092     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 202093     30Q286  Young Women's Leadership School, Astoria  Secondary School
#
# ...

# %%
#rename Regents Exam and others for all schools 
df3= df2.rename(columns={'Regents Exam': 'RegentsExam','Percent Scoring Below 65': 'PercentBelow65', 'Percent Scoring 80 or Above': 'PercentAbove'})
df3.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#            RegentsExam  Year  Total Tested Mean Score PercentBelow65  \
# 0  Common Core Algebra  2017             4          s              s
# 1   Living Environment  2015            16       77.9            6.3
# 2   Living Environment  2016             9         74           11.1
# ...

# %%
#filter by school and Regents Exam "Common Core Algebra" for select school 
df3.loc[(df3['School DBN'] == '30Q286') & (df3['RegentsExam'] == 'Common Core Algebra')]
# Out:
#        School DBN                               School Name      School Level  \
# 16438      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16439      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16440      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48782      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48783      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48784      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48785      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48786      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48787      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 95626      30Q286  Young Women's Leadership School, Astoria  Secondary School
# 95627      30Q286  Young Women's Leadership School, Astoria  Secondary School
# ...

# %%
df['Mean Score']= pd.to_numeric(df['Mean Score'], errors ='coerce')

# %%
df4= df3.loc[(df3['School DBN'] == '30Q286') & (df3['RegentsExam'] == 'Common Core Algebra')]
df4.head(10)
# Out:
#       School DBN                               School Name      School Level  \
# 16438     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16439     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 16440     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48782     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48783     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48784     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48785     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48786     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 48787     30Q286  Young Women's Leadership School, Astoria  Secondary School
# 95626     30Q286  Young Women's Leadership School, Astoria  Secondary School
#
#                RegentsExam  Year  Total Tested Mean Score
# 16438  Common Core Algebra  2015            81       69.4
# ...

# %%
#Mean score for common core algebra for 30Q286
df4.groupby(['Year'])['Mean Score'].mean()
# Out:
# Year
# 2015    68.757143
# 2016    69.690909
# 2017    72.640000
# Name: Mean Score, dtype: float64

# %%
df4.groupby(['Year'])['Mean Score'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#check for missing values in dataset 
df3.isnull().sum()
# Out:
# School DBN         0
# School Name        0
# School Level       0
# RegentsExam       10
# Year               0
# Total Tested       0
# Mean Score         0
# PercentBelow65     0
# PercentAbove       0
# dtype: int64

# %%
#drop percentage columns in 30Q286
drop_cols = ['PercentBelow65', 'PercentAbove']

# %%
df3.drop(drop_cols, inplace =True, axis=1)

# %%
df3.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#            RegentsExam  Year  Total Tested Mean Score
# 0  Common Core Algebra  2017             4          s
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3          s
# ...

# %%
#Group by exam type and number tested
df3.groupby(['RegentsExam'])['Total Tested'].count()
# Out:
# RegentsExam
# Algebra2/Trigonometry              10788
# Common Core Algebra                29254
# Common Core Algebra2                7915
# Common Core English                19878
# Common Core Geometry               15267
# English                            11091
# Geometry                            8509
# Global History and Geography       19192
# Integrated Algebra                 11022
# Living Environment                 25539
# Physical Settings/Chemistry        11670
# Physical Settings/Earth Science    15971
# Physical Settings/Physics           5799
# U.S. History and Government        20426
# Name: Total Tested, dtype: int64

# %%
#total number of results/rows for specific school 
df[df['School DBN'] =='30Q286'].count()
# Out:
# School DBN                     338
# School Name                    338
# School Level                   338
# Regents Exam                   338
# Year                           338
# Total Tested                   338
# Mean Score                     338
# Number Scoring Below 65        338
# Percent Scoring Below 65       338
# Number Scoring 65 or Above     338
# Percent Scoring 65 or Above    338
# Number Scoring 80 or Above     338
# Percent Scoring 80 or Above    338
# Number Scoring CR              338
# Percent Scoring CR             338
# dtype: int64

# %%
df3.head(5)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#            RegentsExam  Year  Total Tested Mean Score
# 0  Common Core Algebra  2017             4          s
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3          s
# 4  Common Core Algebra  2017             2          s

# %%
#Pick a feature/measure/score
#compare above school to secondary schools in the entire dataset
#filter by school and select Regents Exam for all schools
df3.loc[(df3['School Level'] == 'Secondary School') & (df3['RegentsExam'] == 'Common Core Algebra')]
# Out:
#        School DBN                                School Name  \
# 96         01M450                 East Side Community School
# 97         01M450                 East Side Community School
# 397        02M260  M.S. 260 Clinton School Writers & Artists
# 398        02M260  M.S. 260 Clinton School Writers & Artists
# 399        02M260  M.S. 260 Clinton School Writers & Artists
# ...           ...                                        ...
# 212113     84X703           Bronx Preparatory Charter School
# 212114     84X703           Bronx Preparatory Charter School
# 212115     84X703           Bronx Preparatory Charter School
# 212116     84X703           Bronx Preparatory Charter School
# 212117     84X703           Bronx Preparatory Charter School
#
#             School Level          RegentsExam  Year  Total Tested Mean Score
# 96      Secondary School  Common Core Algebra  2016             9       78.2
# 97      Secondary School  Common Core Algebra  2017             6       79.5
# ...

# %%
#drop percentage columns in 30Q286
drop_cols = ['Number Scoring Below 65',
       'Percent Scoring Below 65', 'Number Scoring 65 or Above',
       'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
       'Percent Scoring 80 or Above', 'Number Scoring CR',
       'Percent Scoring CR']

# %%
df.drop(drop_cols, inplace =True, axis=1)

# %%
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score
# 0  Common Core Algebra  2017             4          s
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3          s
# ...

# %%
#mean score comparison by year 2016
df.loc[(df3['School DBN']== '30Q286') & (df3['Year']== 2016) & (df3['RegentsExam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                               School Name  Year  \
# 16439      30Q286  Young Women's Leadership School, Astoria  2016
# 48784      30Q286  Young Women's Leadership School, Astoria  2016
# 48785      30Q286  Young Women's Leadership School, Astoria  2016
# 95629      30Q286  Young Women's Leadership School, Astoria  2016
# 95630      30Q286  Young Women's Leadership School, Astoria  2016
# 95631      30Q286  Young Women's Leadership School, Astoria  2016
# 134087     30Q286  Young Women's Leadership School, Astoria  2016
# 201984     30Q286  Young Women's Leadership School, Astoria  2016
# 201985     30Q286  Young Women's Leadership School, Astoria  2016
# 201986     30Q286  Young Women's Leadership School, Astoria  2016
# 201987     30Q286  Young Women's Leadership School, Astoria  2016
#
#                Regents Exam Mean Score
# 16439   Common Core Algebra       70.3
# 48784   Common Core Algebra       70.9
# 48785   Common Core Algebra       62.6
# ...

# %%
df['Mean Score']= pd.to_numeric(df['Mean Score'], errors ='coerce')

# %%
#mean score for Young Women's Leadership School Astoria
df.loc[(df['School DBN']== '30Q286') & (df['Year']== 2016) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2016.000000
# Total Tested      61.363636
# Mean Score        69.690909
# dtype: float64

# %%
#compare same schools in different districts for Common Core Algebra in 2016  
df.loc[(df['School DBN']== '04M610') & (df3['Year']== 2016) & (df3['RegentsExam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                      School Name  Year         Regents Exam  \
# 3115       04M610  Young Women's Leadership School  2016  Common Core Algebra
# 25139      04M610  Young Women's Leadership School  2016  Common Core Algebra
# 25140      04M610  Young Women's Leadership School  2016  Common Core Algebra
# 62082      04M610  Young Women's Leadership School  2016  Common Core Algebra
# 62083      04M610  Young Women's Leadership School  2016  Common Core Algebra
# 62084      04M610  Young Women's Leadership School  2016  Common Core Algebra
# 108834     04M610  Young Women's Leadership School  2016  Common Core Algebra
# 152451     04M610  Young Women's Leadership School  2016  Common Core Algebra
# 152452     04M610  Young Women's Leadership School  2016  Common Core Algebra
# 152453     04M610  Young Women's Leadership School  2016  Common Core Algebra
# 152454     04M610  Young Women's Leadership School  2016  Common Core Algebra
# ...

# %%
#mean score for Young Women's Leadership School Manhattan
df.loc[(df['School DBN']== '04M610') & (df['Year']== 2016) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2016.000000
# Total Tested      47.083333
# Mean Score        70.787500
# dtype: float64

# %%
#Brooklyn School 
df.loc[(df['School DBN']== '14K614') & (df3['Year']== 2016) & (df3['RegentsExam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                                  School Name  Year  \
# 9377       14K614  Young Women's Leadership School of Brooklyn  2016
# 36364      14K614  Young Women's Leadership School of Brooklyn  2016
# 36365      14K614  Young Women's Leadership School of Brooklyn  2016
# 78204      14K614  Young Women's Leadership School of Brooklyn  2016
# 78205      14K614  Young Women's Leadership School of Brooklyn  2016
# 78206      14K614  Young Women's Leadership School of Brooklyn  2016
# 120703     14K614  Young Women's Leadership School of Brooklyn  2016
# 174867     14K614  Young Women's Leadership School of Brooklyn  2016
# 174868     14K614  Young Women's Leadership School of Brooklyn  2016
# 174869     14K614  Young Women's Leadership School of Brooklyn  2016
# 174870     14K614  Young Women's Leadership School of Brooklyn  2016
# 174871     14K614  Young Women's Leadership School of Brooklyn  2016
#
#                Regents Exam  Mean Score
# ...

# %%
#mean score for Young Women's Leadership School Brooklyn 
df.loc[(df['School DBN']== '14K614') & (df['Year']== 2016) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2016.000000
# Total Tested      41.666667
# Mean Score        63.911111
# dtype: float64

# %%
#Queens
df.loc[(df['School DBN']== '28Q896') & (df3['Year']== 2016) & (df3['RegentsExam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                              School Name  Year  \
# 15834      28Q896  Young Women's Leadership School, Queens  2016
# 47762      28Q896  Young Women's Leadership School, Queens  2016
# 47763      28Q896  Young Women's Leadership School, Queens  2016
# 94209      28Q896  Young Women's Leadership School, Queens  2016
# 94210      28Q896  Young Women's Leadership School, Queens  2016
# 94211      28Q896  Young Women's Leadership School, Queens  2016
# 133005     28Q896  Young Women's Leadership School, Queens  2016
# 199705     28Q896  Young Women's Leadership School, Queens  2016
# 199706     28Q896  Young Women's Leadership School, Queens  2016
# 199707     28Q896  Young Women's Leadership School, Queens  2016
# 199708     28Q896  Young Women's Leadership School, Queens  2016
# 199709     28Q896  Young Women's Leadership School, Queens  2016
#
#                Regents Exam  Mean Score
# 15834   Common Core Algebra        69.5
# ...

# %%
#mean score for Young Women's Leadership School Queens
df.loc[(df['School DBN']== '28Q896') & (df['Year']== 2016) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2016.0000
# Total Tested      73.7500
# Mean Score        68.6125
# dtype: float64

# %%
#Bronx school 
df.loc[(df['School DBN']== '09X568') & (df3['Year']== 2016) & (df3['RegentsExam']== 'Common Core Algebra'), 
       ['School DBN','School Name','Year', 'Regents Exam', 'Mean Score']]
# Out:
#        School DBN                                   School Name  Year  \
# 6045       09X568  Young Women's Leadership School of the Bronx  2016
# 30408      09X568  Young Women's Leadership School of the Bronx  2016
# 30409      09X568  Young Women's Leadership School of the Bronx  2016
# 69727      09X568  Young Women's Leadership School of the Bronx  2016
# 69728      09X568  Young Women's Leadership School of the Bronx  2016
# 69729      09X568  Young Women's Leadership School of the Bronx  2016
# 114353     09X568  Young Women's Leadership School of the Bronx  2016
# 162391     09X568  Young Women's Leadership School of the Bronx  2016
# 162392     09X568  Young Women's Leadership School of the Bronx  2016
# 162393     09X568  Young Women's Leadership School of the Bronx  2016
#
#                Regents Exam  Mean Score
# 6045    Common Core Algebra        73.8
# 30408   Common Core Algebra        75.7
# 30409   Common Core Algebra        64.0
# ...

# %%
#mean score for Young Women's Leadership School BX
df.loc[(df['School DBN']== '09X568') & (df['Year']== 2016) & (df['Regents Exam']== 'Common Core Algebra')].mean()
# Out:
# Year            2016.00
# Total Tested      36.50
# Mean Score        72.35
# dtype: float64

# %%
#include descriptive stats, cleaning task,  visualization, & brief conclusion statement 2-3 sentences.
#import visualization package 
#type of data df.hist() df.plot() df,plot(kind='hist') df.plot(kind="scatter", x='waiting', y='eruptions')

# %%
import matplotlib.pyplot as plot

# %%
# %matplotlib inline

# %%
#display visuals 
df = pd.DataFrame({'School DBN':['30Q286', '09X568', '28Q896', '14K614','04M610'], 'Common Core Algebra':[69.69, 72.35, 68.61, 63.91, 70.79]})
ax = df.plot.bar(x='School DBN', y='Common Core Algebra', rot=0)

# %%
#Conclusion: The Young Women's Leadership School in Astoria showed the highest average test scores on Common Core Algebra in 2017 when compared with 2015 and 2016 - scoring 72.64. 
#Based on the data, the Young Women's Leadership School in the Bronx had a slightly better average score on Common Core Algebra than the other schools in different districts in 2016.
